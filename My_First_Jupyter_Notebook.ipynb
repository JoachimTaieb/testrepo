# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Joachim Taieb**
# Data Intelligence Manager

# %% [markdown]
# *I'm interested in data science to be able to handle massive volume of data. So that I can understand and predict customer behaviour.*

# %% [markdown]
# ### In the next code I'll try to use the Print function

# %%
print("I use the 'Print' function for the first time!")
# Out:
# I use the 'Print' function for the first time!

# %% [markdown]
# ***
#
# * this is a bullet list - line 1
# * this is a bullet list - line 2
#
# 1. this is a numbered list - line 1
# 2. this is a numbered list - line 2
#
# | FIrst Name | Last Name | Role |
# | - | - | - |
# | Joachim | Taieb | Father |
# | Justine | Migeotte | Mother |
#
# The website of my `company` is <a href="http://www.lemonde.fr" target="_blank">www.lemonde.fr</a>.
#
# ![Markdown Logo is here.](https://img.lemde.fr/2022/10/21/3/0/5900/3933/664/0/75/0/f8ee14c_1666361746584-jmug220507068.jpg)
